# %% [markdown]
# # IMPORTING TENSORFLOW

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (6.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (2.3.2)
# Requirement already satisfied: h5py>=3.11.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\ai-ml\project\smart-garbage-segregation\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %% [markdown]
# # IMPORTING TENSORFLOW

# %%
import tensorflow as tf

# %% [markdown]
# # USING CPU

# %%
device = "/device:CPU:0"

# %% [markdown]
# # DATA IMPORTING

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import math

dir_example = "Data"

classes = os.listdir(dir_example)
print(classes)
# Out:
# ['Test', 'Train']

# %%
dir_example = "Data/Train"

train_classes = os.listdir(dir_example)
print(train_classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# # DATA VISUALIZATION

# %%
dir_with_examples = 'visualize'
files_per_row = 6
files_in_dir = os.listdir(dir_with_examples)
number_of_cols = files_per_row
number_of_rows = int(len(files_in_dir) / number_of_cols)

# Generate the subplots
fig, axs = plt.subplots(number_of_rows, number_of_cols)
fig.set_size_inches(20, 15, forward=True)

# Map each file to subplot
try:
  for i in range(0, len(files_in_dir)):
    file_name = files_in_dir[i]
    image = Image.open(f'{dir_with_examples}/{file_name}')
    row = math.floor(i / files_per_row)
    col = i % files_per_row
    axs[col].imshow(image)
    axs[col].axis('off')
except:
  pass
# Show the plot
plt.show()

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, SpatialDropout2D
from tensorflow.keras.losses import sparse_categorical_crossentropy, binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # PREPARING OF DATA

# %%
train = 'Data/Train'
test = 'Data/Test'

# %%
train_generator = ImageDataGenerator(rescale = 1/255)

train_generator = train_generator.flow_from_directory(train,
                                                      target_size = (300,300),
                                                      batch_size = 32,
                                                      class_mode = 'sparse')

labels = (train_generator.class_indices)
print(labels,'\n')

labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 2186 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32,))

# %%
test_generator = ImageDataGenerator(rescale = 1./255)

test_generator = test_generator.flow_from_directory(test,
                                                    target_size = (300,300),
                                                    batch_size = 32,
                                                    class_mode = 'sparse')

test_labels = (test_generator.class_indices)
print(test_labels,'\n')

test_labels = dict((v,k) for k,v in test_labels.items())
print(test_labels)
# Out:
# Found 346 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %% [markdown]
# # Importing oneDNN

# %%
# import oneDNN as dnn

# %% [markdown]
# # LABELING

# %%
print(train_generator.class_indices)
Labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('Labels.txt', 'w') as file:
  file.write(Labels)
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %% [markdown]
# # CREATING MODEL WITH oneDNN OPTIMIZATION

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '1'

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

# Convolution blocks
model.add(Conv2D(32, kernel_size=(3,3), padding='same', input_shape=(300,300,3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

# Classification layers
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(6, activation='softmax'))
# Out:
# d:\AI-ML\Project\Smart-Garbage-Segregation\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # COMPILING MODEL  # Enable OneDNN optimizations

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 300, 300, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 150, 150, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 150, 150, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 75, 75, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 43808)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     2,803,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,843,910 (10.85 MB)
#  Trainable params: 2,843,910 (10.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # TRAINING THE MODEL(10 EPOCHS)

# %%
model.fit(train_generator,
          epochs=10,
          steps_per_epoch=2184//32)
# Out:
# d:\AI-ML\Project\Smart-Garbage-Segregation\venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - accuracy: 0.2112 - loss: 1.7686
# Epoch 2/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2500 - loss: 1.7555
# Epoch 3/10
# d:\AI-ML\Project\Smart-Garbage-Segregation\venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.2897 - loss: 1.6494
# Epoch 4/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2188 - loss: 1.6027
# Epoch 5/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.3751 - loss: 1.4880
# Epoch 6/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 262us/step - accuracy: 0.4688 - loss: 1.4464
# Epoch 7/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.4494 - loss: 1.3582
# Epoch 8/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5312 - loss: 1.1220
# Epoch 9/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.4796 - loss: 1.2837
# Epoch 10/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.4688 - loss: 1.4388

# %% [markdown]
# # TESTING PREDICTION

# %%
import keras.utils as ku
import numpy as np

# %%
test_img = 'Data/Test/paper/paper522.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 31s 31s/step
# Probability: 0.8901125
# Classified: paper
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 6.57 %
# GLASS : 0.27 %
# METAL : 2.12 %
# PAPER : 89.01 %
# PLASTIC : 1.78 %
# TRASH : 0.25 %

# %%
test_img = 'Data/Test/metal/metal386.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Probability: 0.3127439
# Classified: paper
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 5.73 %
# GLASS : 17.08 %
# METAL : 17.33 %
# PAPER : 31.27 %
# PLASTIC : 24.42 %
# TRASH : 4.16 %

# %%
test_img = 'Data/Test/plastic/plastic430.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# Probability: 0.36488414
# Classified: plastic
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 3.51 %
# GLASS : 26.57 %
# METAL : 13.19 %
# PAPER : 16.18 %
# PLASTIC : 36.49 %
# TRASH : 4.07 %

# %%
test_img = 'Data/Test/cardboard/cardboard355.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Probability: 0.9951751
# Classified: cardboard
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 99.52 %
# GLASS : 0.12 %
# METAL : 0.08 %
# PAPER : 0.02 %
# PLASTIC : 0.08 %
# TRASH : 0.18 %

# %% [markdown]
# # SAVING THE TRAINED MODEL

# %%
model.save('modelnew.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
